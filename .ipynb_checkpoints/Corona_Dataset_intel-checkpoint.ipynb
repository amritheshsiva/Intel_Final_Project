# %%
from __future__ import print_function
import os
data_path = ['data']

# %%
import pandas as pd

# Import the data using the file path
filepath = os.sep.join(data_path + ['Covid Data.csv'])
data = pd.read_csv('Covid Data.csv')
data
# Out:
#         USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0           2             1    1             1  03/05/2020       97
# 1           2             1    2             1  03/06/2020       97
# 2           2             1    2             2  09/06/2020        1
# 3           2             1    1             1  12/06/2020       97
# 4           2             1    2             1  21/06/2020       97
# ...       ...           ...  ...           ...         ...      ...
# 134280      1             4    2             2  9999-99-99        2
# 134281      2             4    1             1  9999-99-99       97
# 134282      2             4    1             1  9999-99-99       97
# 134283      2             4    2             1  9999-99-99       97
# 134284      1             4    1             1  9999-99-99       97
#
#         PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0               1   65         2         2  ...       2        2
# ...

# %%
data.head(1).T
# Out:
#                                0
# USMER                          2
# MEDICAL_UNIT                   1
# SEX                            1
# PATIENT_TYPE                   1
# DATE_DIED             03/05/2020
# INTUBED                       97
# PNEUMONIA                      1
# AGE                           65
# PREGNANT                       2
# DIABETES                       2
# COPD                           2
# ASTHMA                         2
# INMSUPR                        2
# HIPERTENSION                   1
# OTHER_DISEASE                2.0
# CARDIOVASCULAR               2.0
# OBESITY                      2.0
# RENAL_CHRONIC                2.0
# TOBACCO                      2.0
# CLASIFFICATION_FINAL         3.0
# ICU                         97.0

# %%
data.drop(['DATE_DIED','CARDIOVASCULAR','OBESITY','RENAL_CHRONIC','TOBACCO','CLASIFFICATION_FINAL','ICU'], axis=1, inplace=True)
data
# Out:
#         USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  INTUBED  PNEUMONIA  AGE  \
# 0           2             1    1             1       97          1   65
# 1           2             1    2             1       97          1   72
# 2           2             1    2             2        1          2   55
# 3           2             1    1             1       97          2   53
# 4           2             1    2             1       97          2   68
# ...       ...           ...  ...           ...      ...        ...  ...
# 134280      1             4    2             2        2          2   69
# 134281      2             4    1             1       97          1   54
# 134282      2             4    1             1       97          2   55
# 134283      2             4    2             1       97          2   53
# 134284      1             4    1             1       97          2   46
#
#         PREGNANT  DIABETES  COPD  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE
# ...

# %%
data.drop(['OTHER_DISEASE','HIPERTENSION'], axis=1, inplace=True)
data
# Out:
#         USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  INTUBED  PNEUMONIA  AGE  \
# 0           2             1    1             1       97          1   65
# 1           2             1    2             1       97          1   72
# 2           2             1    2             2        1          2   55
# 3           2             1    1             1       97          2   53
# 4           2             1    2             1       97          2   68
# ...       ...           ...  ...           ...      ...        ...  ...
# 134280      1             4    2             2        2          2   69
# 134281      2             4    1             1       97          1   54
# 134282      2             4    1             1       97          2   55
# 134283      2             4    2             1       97          2   53
# 134284      1             4    1             1       97          2   46
#
#         PREGNANT  DIABETES  COPD  ASTHMA  INMSUPR
# 0              2         2     2       2        2
# ...

# %%
data.fillna(0, inplace=True)
data
# Out:
#         USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  INTUBED  PNEUMONIA  AGE  \
# 0           2             1    1             1       97          1   65
# 1           2             1    2             1       97          1   72
# 2           2             1    2             2        1          2   55
# 3           2             1    1             1       97          2   53
# 4           2             1    2             1       97          2   68
# ...       ...           ...  ...           ...      ...        ...  ...
# 134280      1             4    2             2        2          2   69
# 134281      2             4    1             1       97          1   54
# 134282      2             4    1             1       97          2   55
# 134283      2             4    2             1       97          2   53
# 134284      1             4    1             1       97          2   46
#
#         PREGNANT  DIABETES  COPD  ASTHMA  INMSUPR
# 0              2         2     2       2        2
# ...

# %%
data.drop(['INMSUPR'], axis=1, inplace=True)
data
# Out:
#         USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  INTUBED  PNEUMONIA  AGE  \
# 0           2             1    1             1       97          1   65
# 1           2             1    2             1       97          1   72
# 2           2             1    2             2        1          2   55
# 3           2             1    1             1       97          2   53
# 4           2             1    2             1       97          2   68
# ...       ...           ...  ...           ...      ...        ...  ...
# 134280      1             4    2             2        2          2   69
# 134281      2             4    1             1       97          1   54
# 134282      2             4    1             1       97          2   55
# 134283      2             4    2             1       97          2   53
# 134284      1             4    1             1       97          2   46
#
#         PREGNANT  DIABETES  COPD  ASTHMA
# 0              2         2     2       2
# ...

# %%
data.fillna(0, inplace=True)
data
# Out:
#         USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE  INTUBED  PNEUMONIA  AGE  \
# 0           2             1    1             1       97          1   65
# 1           2             1    2             1       97          1   72
# 2           2             1    2             2        1          2   55
# 3           2             1    1             1       97          2   53
# 4           2             1    2             1       97          2   68
# ...       ...           ...  ...           ...      ...        ...  ...
# 134280      1             4    2             2        2          2   69
# 134281      2             4    1             1       97          1   54
# 134282      2             4    1             1       97          2   55
# 134283      2             4    2             1       97          2   53
# 134284      1             4    1             1       97          2   46
#
#         PREGNANT  DIABETES  COPD  ASTHMA
# 0              2         2     2       2
# ...

# %%
x_cols = [x for x in data.columns if x != "ASTHMA"]

X_data = data[x_cols]
y_data = data["ASTHMA"]
X_data
y_data
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2
#          ..
# 134280    2
# 134281    2
# 134282    2
# 134283    2
# 134284    2
# Name: ASTHMA, Length: 134285, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=3)

knn = knn.fit(X_data, y_data)

y_pred = knn.predict(X_data)

# %%
def accuracy(real, predict):
    return sum(y_data == y_pred) / float(real.shape[0])

# %%
print(accuracy(y_data, y_pred))
# Out:
# 0.9662210969207283
